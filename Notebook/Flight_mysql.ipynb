# %%
#! pip install mysql-connector-python

# %%
import mysql.connector as conn
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
conn.connect(host="localhost",user="root",passwd="0000")

# %%
mydb=conn.connect(host="localhost",user="root",passwd="0000")

# %%
mydb

# %%
cursor=mydb.cursor()

# %%
cursor

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('ankit',),
#  ('classicmodels',),
#  ('information_schema',),
#  ('ml_project',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sql1',),
#  ('sys',),
#  ('testmudit',)]

# %%
cursor=mydb.cursor()

# %%
#cursor.execute('create database ml_project')

# %%
cursor.execute("use ml_project")

# %% [markdown]
# ## Creating CSV file for inserting data in sql

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw_clean_data.csv')
df.head(1)
# Out:
#    Unnamed: 0 Airline    Source Destination  Total_Stops  Price  Day  Month  \
# 0           0  IndiGo  Banglore   New Delhi            0   3897   24      3
#
#    Dep_hour  Dep_minute  Duration_hour  Duration_minute
# 0        22          20              2               50

# %%
df2= pd.DataFrame()

# %%
df2['Airline'] ="'"+ df.Airline+ "'"

# %%
df2['Source'] ="'"+ df.Source+ "'"

# %%
df2['destination'] ="'"+ df.Destination+ "'"

# %%
df2
# Out:
#              Airline      Source  destination
# 0           'IndiGo'  'Banglore'  'New Delhi'
# 1        'Air India'   'Kolkata'   'Banglore'
# 2      'Jet Airways'     'Delhi'     'Cochin'
# 3           'IndiGo'   'Kolkata'   'Banglore'
# 4           'IndiGo'  'Banglore'  'New Delhi'
# ...              ...         ...          ...
# 10420     'Air Asia'   'Kolkata'   'Banglore'
# 10421    'Air India'   'Kolkata'   'Banglore'
# 10422  'Jet Airways'  'Banglore'      'Delhi'
# 10423      'Vistara'  'Banglore'  'New Delhi'
# 10424    'Air India'     'Delhi'     'Cochin'
#
# [10425 rows x 3 columns]

# %%
df['Airline'] = df2.Airline

# %%
df['Source'] = df2.Source

# %%
df['Destination'] = df2.destination

# %%
df
# Out:
#        Unnamed: 0        Airline      Source  Destination  Total_Stops  Price  \
# 0               0       'IndiGo'  'Banglore'  'New Delhi'            0   3897
# 1               1    'Air India'   'Kolkata'   'Banglore'            2   7662
# 2               2  'Jet Airways'     'Delhi'     'Cochin'            2  13882
# 3               3       'IndiGo'   'Kolkata'   'Banglore'            1   6218
# 4               4       'IndiGo'  'Banglore'  'New Delhi'            1  13302
# ...           ...            ...         ...          ...          ...    ...
# 10420       10678     'Air Asia'   'Kolkata'   'Banglore'            0   4107
# 10421       10679    'Air India'   'Kolkata'   'Banglore'            0   4145
# 10422       10680  'Jet Airways'  'Banglore'      'Delhi'            0   7229
# 10423       10681      'Vistara'  'Banglore'  'New Delhi'            0  12648
# 10424       10682    'Air India'     'Delhi'     'Cochin'            2  11753
#
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.to_csv('Trial.csv')

# %% [markdown]
# ## Inserting data in sql

# %%
import csv
with open('Trial.csv','r') as f:
    raw_clean_data=csv.reader(f,delimiter='\n')
    cnt=0
    for i in raw_clean_data:
        if cnt==0:
            cnt+=1
            continue
        print(i[0])
        #df = pd.read_csv
# Out:
# 0,'IndiGo','Banglore','New Delhi',0,3897,24,3,22,20,2,50
# 1,'Air India','Kolkata','Banglore',2,7662,5,1,5,50,7,25
# 2,'Jet Airways','Delhi','Cochin',2,13882,6,9,9,25,19,0
# 3,'IndiGo','Kolkata','Banglore',1,6218,5,12,18,5,5,25
# 4,'IndiGo','Banglore','New Delhi',1,13302,3,1,16,50,4,45
# 5,'SpiceJet','Kolkata','Banglore',0,3873,24,6,9,0,2,25
# 6,'Jet Airways','Banglore','New Delhi',1,11087,3,12,18,55,15,30
# 7,'Jet Airways','Banglore','New Delhi',1,22270,3,1,8,0,21,5
# 8,'Jet Airways','Banglore','New Delhi',1,11087,3,12,8,55,25,30
# 9,'Multiple carriers','Delhi','Cochin',1,8625,27,5,11,25,7,50
# 10,'Air India','Delhi','Cochin',1,8907,6,1,9,45,13,15
# 11,'IndiGo','Kolkata','Banglore',0,4174,18,4,20,20,2,35
# 12,'Air India','Chennai','Kolkata',0,4667,24,6,11,40,2,15
# 13,'Jet Airways','Kolkata','Banglore',1,9663,5,9,21,10,12,10
# 14,'IndiGo','Kolkata','Banglore',0,4804,24,4,17,15,2,35
# 15,'Air India','Delhi','Cochin',2,14011,3,3,16,40,26,35
# ...

# %%
#cursor.execute('create table flight (id int,Airlline varchar(100),source varchar(100),destination varchar(100),total_stops int,price int,day int,month int,dep_hpir int,dep_minut int,duration_hur int,duration_minute int)')

# %%
#cursor.execute("drop table flight")

# %%
#mydb.commit()

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('flight',)]

# %%
import csv
with open('Trial.csv','r') as f:
    data=csv.reader(f,delimiter='\n')
    cnt=0
    for i in data:
        if cnt==0:
            cnt+=1
            continue
        #print(i[0])
        #print(f'insert into data values ({i[0]})')
        #cursor.execute('insert into flight values({values})'.format(values = ((i[0]))))  #Do not rerun it will add data again

# %%
mydb.commit()

# %%
df.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df.head(1)
#
# NameError: name 'df' is not defined

# %%
cursor.execute('select * from ml_project.flight')

# %%
cursor.fetchall()
# Out:
# [(0, 'IndiGo', 'Banglore', 'New Delhi', 0, 3897, 24, 3, 22, 20, 2, 50),
#  (1, 'Air India', 'Kolkata', 'Banglore', 2, 7662, 5, 1, 5, 50, 7, 25),
#  (2, 'Jet Airways', 'Delhi', 'Cochin', 2, 13882, 6, 9, 9, 25, 19, 0),
#  (3, 'IndiGo', 'Kolkata', 'Banglore', 1, 6218, 5, 12, 18, 5, 5, 25),
#  (4, 'IndiGo', 'Banglore', 'New Delhi', 1, 13302, 3, 1, 16, 50, 4, 45),
#  (5, 'SpiceJet', 'Kolkata', 'Banglore', 0, 3873, 24, 6, 9, 0, 2, 25),
#  (6, 'Jet Airways', 'Banglore', 'New Delhi', 1, 11087, 3, 12, 18, 55, 15, 30),
#  (7, 'Jet Airways', 'Banglore', 'New Delhi', 1, 22270, 3, 1, 8, 0, 21, 5),
#  (8, 'Jet Airways', 'Banglore', 'New Delhi', 1, 11087, 3, 12, 8, 55, 25, 30),
#  (9, 'Multiple carriers', 'Delhi', 'Cochin', 1, 8625, 27, 5, 11, 25, 7, 50),
#  (10, 'Air India', 'Delhi', 'Cochin', 1, 8907, 6, 1, 9, 45, 13, 15),
#  (11, 'IndiGo', 'Kolkata', 'Banglore', 0, 4174, 18, 4, 20, 20, 2, 35),
#  (12, 'Air India', 'Chennai', 'Kolkata', 0, 4667, 24, 6, 11, 40, 2, 15),
# ...

# %%
df.head(1)
# Out:
#     Airline      Source  Destination  Total_Stops  Price  Day  Month  \
# 0  'IndiGo'  'Banglore'  'New Delhi'            0   3897   24      3
#
#    Dep_hour  Dep_minute  Duration_hour  Duration_minute
# 0        22          20              2               50

# %% [markdown]
# ## Reading Data from SQL

# %%
cursor.execute("Select * from ml_project.flight")

# %%
df4 = pd.DataFrame(cursor.fetchall(), columns=['sno','Airline','Source','Destination','Total_Stops','Price',
                                               'Day','Month','Dep_hour','Dep_minute','Duration_hour','Duration_minute'],)
df4
# Out:
#          sno      Airline    Source Destination  Total_Stops  Price  Day  \
# 0          0       IndiGo  Banglore   New Delhi            0   3897   24
# 1          1    Air India   Kolkata    Banglore            2   7662    5
# 2          2  Jet Airways     Delhi      Cochin            2  13882    6
# 3          3       IndiGo   Kolkata    Banglore            1   6218    5
# 4          4       IndiGo  Banglore   New Delhi            1  13302    3
# ...      ...          ...       ...         ...          ...    ...  ...
# 10420  10420     Air Asia   Kolkata    Banglore            0   4107    4
# 10421  10421    Air India   Kolkata    Banglore            0   4145   27
# 10422  10422  Jet Airways  Banglore       Delhi            0   7229   27
# 10423  10423      Vistara  Banglore   New Delhi            0  12648    3
# 10424  10424    Air India     Delhi      Cochin            2  11753    5
#
#        Month  Dep_hour  Dep_minute  Duration_hour  Duration_minute
# ...

# %%
type(df4)
# Out:
# pandas.core.frame.DataFrame
